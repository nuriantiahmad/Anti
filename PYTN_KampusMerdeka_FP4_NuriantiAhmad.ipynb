# %% [markdown]
# # Final Project 4

# %% [markdown]
# # A. Perkenalan

# %% [markdown]
# Team :
# 1. Cindo Fara
# 2. Nurianti Ahmad

# %% [markdown]
# # Projects Overview
#
# Data ini berisi transaksi pengguna kartu kredit sebanyak 9000 orang selama 6 bulan. Data
# ini memiliki 18 atribut.

# %% [markdown]
# # Attribute Information :
# 1. CUSTID - Identification of Credit Card holder (Categorical)
# 2. BALANCE - Balance amount left in their account to make purchases (
# 3. BALANCEFREQUENCY - How frequently the Balance is updated, score between 0
# and 1 (1 = frequently updated, 0 = not frequently updated)
# 4. PURCHASES - Amount of purchases made from account
# 5. ONEOFFPURCHASES - Maximum purchase amount done in one-go
# 6. INSTALLMENTSPURCHASES - Amount of purchase done in installment
# 7. CASHADVANCE - Cash in advance given by the user
# 8. PURCHASESFREQUENCY - How frequently the Purchases are being made, score
# between 0 and 1 (1 = frequently purchased, 0 = not frequently purchased)
# 9. ONEOFFPURCHASESFREQUENCY - How frequently Purchases are happening in
# one-go (1 = frequently purchased, 0 = not frequently purchased)
# 10. PURCHASESINSTALLMENTSFREQUENCY - How frequently purchases in
# installments are being done (1 = frequently done, 0 = not frequently done)
# 11. CASHADVANCEFREQUENCY - How frequently the cash in advance being paid
# 12. CASHADVANCETRX - Number of Transactions made with "Cash in Advance"
# 13. PURCHASESTRX - Number of purchase transactions made
# 14. CREDITLIMIT - Limit of Credit Card for user
# 15. PAYMENTS - Amount of Payment done by user
# 16. MINIMUM_PAYMENTS - Minimum amount of payments made by user
# 17. PRCFULLPAYMENT - Percent of full payment paid by user
# 18. TENURE - Tenure of credit card service for use

# %% [markdown]
# # Objective
# Final Project 4 ini dibuat guna mengevaluasi konsep Clustering sebagai berikut:
# - Mampu memahami konsep Clustering dengan menggunakan Scikit-Learn
# - Mampu mempersiapkan data untuk digunakan dalam Clustering
# - Mampu mengimplementasikan Clustering pada data yang diberikan

# %% [markdown]
# # B. Import Library

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import f1_score, average_precision_score, accuracy_score
from sklearn.metrics import confusion_matrix, classification_report, precision_score, recall_score
from sklearn.preprocessing import StandardScaler, normalize,RobustScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA 
from sklearn.model_selection import train_test_split

from umap import UMAP

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # D. Data Loading
# Pada Tahap Data Loading, hal yang dilakukan adalah :
# - Mengimpor dataset
# - Menampilkan tabel dataset (teratas dan terbawah)
# - Melihat jumlah baris dan kolom
# - Melihat informasi tiap variabel

# %%
# Mengimpor dataset
df = pd.read_csv("CC GENERAL.csv")
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000               NaN          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
df.tail()
# Out:
#      CUST_ID     BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 8945  C19186   28.493517           1.000000     291.12              0.00
# 8946  C19187   19.183215           1.000000     300.00              0.00
# 8947  C19188   23.398673           0.833333     144.40              0.00
# 8948  C19189   13.457564           0.833333       0.00              0.00
# 8949  C19190  372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 8945                    0.000000                          0.833333
# 8946                    0.000000                          0.833333
# 8947                    0.000000                          0.666667
# 8948                    0.000000                          0.000000
# 8949                    0.666667                          0.000000
#
#       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 8945                0.000000                 0              6        1000.0
# 8946                0.000000                 0              6        1000.0
# 8947                0.000000                 0              5        1000.0
# 8948                0.166667                 2              0         500.0
# 8949                0.333333                 2             23        1200.0
#
#         PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 8945  325.594462         48.886365              0.50       6
# 8946  275.861322               NaN              0.00       6
# 8947   81.270775         82.418369              0.25       6
# 8948   52.549959         55.755628              0.25       6
# 8949   63.165404         88.288956              0.00       6

# %%
df.shape
# Out:
# (8950, 18)

# %% [markdown]
# Terdapat 8950 baris dan 18 kolom

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 18 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8949 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8637 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
# dtypes: float64(14), int64(3), object(1)
# memory usage: 1.2+ MB

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# # D. Data Cleaning
# Pada tahap data cleaning, hal yang dilakukan adalah :
# - Mengecek missing value
# - Cek duplikasi data

# %%
# Describe the data
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8950.000000        8950.000000   8950.000000       8950.000000
# mean    1564.474828           0.877271   1003.204834        592.437371
# std     2081.531879           0.236904   2136.634782       1659.887917
# min        0.000000           0.000000      0.000000          0.000000
# 25%      128.281915           0.888889     39.635000          0.000000
# 50%      873.385231           1.000000    361.280000         38.000000
# 75%     2054.140036           1.000000   1110.130000        577.405000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8950.000000   8950.000000          8950.000000
# mean               411.067645    978.871112             0.490351
# std                904.338115   2097.163877             0.401371
# min                  0.000000      0.000000             0.000000
# 25%                  0.000000      0.000000             0.083333
# 50%                 89.000000      0.000000             0.500000
# 75%                468.637500   1113.821139             0.916667
# max              22500.000000  47137.211760             1.000000
#
#        ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# count                 8950.000000                       8950.000000
# mean                     0.202458                          0.364437
# std                      0.298336                          0.397448
# min                      0.000000                          0.000000
# 25%                      0.000000                          0.000000
# 50%                      0.083333                          0.166667
# 75%                      0.300000                          0.750000
# max                      1.000000                          1.000000
#
#        CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# count             8950.000000       8950.000000    8950.000000   8949.000000
# mean                 0.135144          3.248827      14.709832   4494.449450
# std                  0.200121          6.824647      24.857649   3638.815725
# min                  0.000000          0.000000       0.000000     50.000000
# 25%                  0.000000          0.000000       1.000000   1600.000000
# 50%                  0.000000          0.000000       7.000000   3000.000000
# 75%                  0.222222          4.000000      17.000000   6500.000000
# max                  1.500000        123.000000     358.000000  30000.000000
#
#            PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT       TENURE
# count   8950.000000       8637.000000       8950.000000  8950.000000
# mean    1733.143852        864.206542          0.153715    11.517318
# std     2895.063757       2372.446607          0.292499     1.338331
# min        0.000000          0.019163          0.000000     6.000000
# 25%      383.276166        169.123707          0.000000    12.000000
# 50%      856.901546        312.343947          0.000000    12.000000
# 75%     1901.134317        825.485459          0.142857    12.000000
# max    50721.483360      76406.207520          1.000000    12.000000

# %% [markdown]
# Mean BALANCE is $1,564
#
# BALANCE_FREQUENCY is frequently updated on average ~0.9
#
# PURCHASES average is $1,000
#
# ONEOFF_PURCHASES average is ~$600
#
# Average PURCHASES_FREQUENCY is around 0.5
#
# Average ONEOFF_PURCHASES_FREQUENCY, PURCHASES_INSTALLMENTS_FREQUENCY, and CASH_ADVANCE_FREQUENCY
#
# Average CREDIT_LIMIT is ~$4,500
#
# Average PRC_FULL_PAYMENT is 15%
#
# Average TENURE is 11.5 years

# %%
# Custom colors
class clr:
    S = '\033[1m' + '\033[92m'
    E = '\033[0m' 

# Check the missing data
print(df.isnull().sum())
print(clr.S+'----------------------------------------\n Percentage of missing data: \n'+clr.E)
print((df[['MINIMUM_PAYMENTS', 'CREDIT_LIMIT']].isnull().sum()/df['CUST_ID'].count())*100)
# Out:
# CUST_ID                               0
# BALANCE                               0
# BALANCE_FREQUENCY                     0
# PURCHASES                             0
# ONEOFF_PURCHASES                      0
# INSTALLMENTS_PURCHASES                0
# CASH_ADVANCE                          0
# PURCHASES_FREQUENCY                   0
# ONEOFF_PURCHASES_FREQUENCY            0
# PURCHASES_INSTALLMENTS_FREQUENCY      0
# CASH_ADVANCE_FREQUENCY                0
# CASH_ADVANCE_TRX                      0
# PURCHASES_TRX                         0
# CREDIT_LIMIT                          1
# PAYMENTS                              0
# MINIMUM_PAYMENTS                    313
# PRC_FULL_PAYMENT                      0
# TENURE                                0
# dtype: int64
# ----------------------------------------
#  Percentage of missing data:
#
# MINIMUM_PAYMENTS    3.497207
# CREDIT_LIMIT        0.011173
# dtype: float64

# %%
print(df[['MINIMUM_PAYMENTS', 'CREDIT_LIMIT']].isnull().sum())
# print(df[['MINIMUM_PAYMENTS', 'CREDIT_LIMIT']].isnull())
# Out:
# MINIMUM_PAYMENTS    313
# CREDIT_LIMIT          1
# dtype: int64

# %%
print(df['CUST_ID'].count())
# Out:
# 8950

# %% [markdown]
# Dilanjutkan dengan mengisi missing elements dengan nilai rata-rata dari setiap variabel

# %% [markdown]
# <!-- dilanjutkan dengan mengisi missing elements dengan nilai rata2 dari setiap variabel -->

# %%
# Fill up the missing elements with mean of the MINIMUM_PAYMENTS
df.loc[(df['MINIMUM_PAYMENTS'].isnull() == True), 
                  'MINIMUM_PAYMENTS'] = df['MINIMUM_PAYMENTS'].mean()

# Fill up the missing elements with mean of the CREDIT_LIMIT
df.loc[(df['CREDIT_LIMIT'].isnull() == True), 
                  'CREDIT_LIMIT'] = df['CREDIT_LIMIT'].mean()

df.isnull().sum()
# Out:
# CUST_ID                             0
# BALANCE                             0
# BALANCE_FREQUENCY                   0
# PURCHASES                           0
# ONEOFF_PURCHASES                    0
# INSTALLMENTS_PURCHASES              0
# CASH_ADVANCE                        0
# PURCHASES_FREQUENCY                 0
# ONEOFF_PURCHASES_FREQUENCY          0
# PURCHASES_INSTALLMENTS_FREQUENCY    0
# CASH_ADVANCE_FREQUENCY              0
# CASH_ADVANCE_TRX                    0
# PURCHASES_TRX                       0
# CREDIT_LIMIT                        0
# PAYMENTS                            0
# MINIMUM_PAYMENTS                    0
# PRC_FULL_PAYMENT                    0
# TENURE                              0
# dtype: int64

# %%
# Chek duplicated entries in the data
df2 = df.copy()
print(clr.S+'Duplicated in this dataset:'+clr.E, df.duplicated().sum())
# Out:
# Duplicated in this dataset: 0

# %% [markdown]
# tidak terdapat duplikasi data

# %% [markdown]
# # menghilangkan kolom Customer ID
# Hal ini dilakukan karena kolom customer id tidak dibutuhkan dalam clustering

# %%
# Drop Customer ID column 'CUST_ID'
df2.drop('CUST_ID', axis = 1, inplace = True)
df2.head()
# Out:
#        BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0    40.900749           0.818182      95.40              0.00
# 1  3202.467416           0.909091       0.00              0.00
# 2  2495.148862           1.000000     773.17            773.17
# 3  1666.670542           0.636364    1499.00           1499.00
# 4   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        864.206542          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %%
# Get the column names
df2.columns
# Out:
# Index(['BALANCE', 'BALANCE_FREQUENCY', 'PURCHASES', 'ONEOFF_PURCHASES',
#        'INSTALLMENTS_PURCHASES', 'CASH_ADVANCE', 'PURCHASES_FREQUENCY',
#        'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY',
#        'CASH_ADVANCE_FREQUENCY', 'CASH_ADVANCE_TRX', 'PURCHASES_TRX',
#        'CREDIT_LIMIT', 'PAYMENTS', 'MINIMUM_PAYMENTS', 'PRC_FULL_PAYMENT',
#        'TENURE'],
#       dtype='object')

# %% [markdown]
# # E. Exploratory data

# %%
# Plot the distribution
plt.figure(figsize = (10,50))
for i in range(len(df2.columns)):
    plt.subplot(17,1,i+1)
    sns.distplot(df2[df2.columns[i]], 
                 kde_kws={'color':'black', 'lw':2, 'label':'KDE'}, hist_kws={'color':'blue'})                 
    plt.title(df2.columns[i], color= 'darkgreen', y=1.03)
plt.tight_layout()

# %% [markdown]
# dari data terlihat jelas bahwa kebanyakan kolom itu memiliki banyak outlier, dibuktikan dari beberapa grafik nya yang skew negatif dan positif dan tidak terdistribusi di tengah(normal distribution), maka dalam kasus ini saya akan melakukan normalisasi data menggunakan robust scaler disebabkan robust scaler akan melakukan normalisasi data dengan memperhitungkan nilai outliernya.

# %% [markdown]
# # F. Pre-processing data
# - darisini kita akan melakukan elbow method untuk sekedar menjadikan acuan rekomendasi untuk menentukan jumlah cluster, dan bukan menjadikan elbow ini sebagai acuan inti sebagai penentuan clusternya, sebab kembali pada algoritma ini bahwa clustering merupakan metode exploratif bukan metode inferensia(predictif).

# %%
# Scale the data first
scaler = RobustScaler()
df_scaled = scaler.fit_transform(df2)
df_scaled.shape
# Out:
# (8950, 17)

# %%
df_scaled
# Out:
# array([[-0.43226678, -1.63636364, -0.24837108, ..., -0.28285691,
#          0.        ,  0.        ],
#        [ 1.20937371, -0.81818182, -0.33748873, ...,  1.06254141,
#          1.55555556,  0.        ],
#        [ 0.84209923,  0.        ,  0.38476593, ...,  0.42064894,
#          0.        ,  0.        ],
#        ...,
#        [-0.44135471, -1.5000045 , -0.20259786, ..., -0.36519846,
#          1.75000175, -6.        ],
#        [-0.44651662, -1.5000045 , -0.33748873, ..., -0.40365347,
#          1.75000175, -6.        ],
#        [-0.25997614, -3.        ,  0.68376779, ..., -0.35673145,
#          0.        , -6.        ]])

# %%
scores_1 = []
range_values = range(1,12)

for i in range_values:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(df_scaled)
    scores_1.append(kmeans.inertia_)

plt.figure(figsize = (12,6), facecolor = '#FFF8EA') 
plt.plot(scores_1, 'bx-', marker = 'o', color = '#9E7676')
plt.xlabel('Values of K', fontsize = 8, color='#815B5B')
plt.title('Elbow Method', fontsize = 14, color='#815B5B', y=1.03);

# %% [markdown]
# Kita dapat mengamati bahwa, klaster ke-4 tampaknya membentuk siku-siku dari kurva. Namun, nilai-nilai tersebut tidak berkurang secara linear hingga klaster ke-8. Mari kita pilih jumlah cluster menjadi 7 atau 8, namun balik lagi bahwa elbow method ini tidak bisa menjadi acuan utama yang menjadikan cluster itu harus di cluster 7 atau 8, namun sekedar rekomendasi awal saja, perlu analisis lanjutan untuk menentukan cluster tersebut secara optimal.

# %% [markdown]
# # H. Pelatihan Model

# %% [markdown]
# ## K-Means

# %%
kmeans = KMeans(n_clusters=7, random_state=1)
kmeans.fit(df_scaled)
labels = kmeans.labels_ # Labels (cluster) associated to each data point

kmeans.cluster_centers_.shape
# Out:
# (7, 17)

# %%
labels[0:11]
# Out:
# array([0, 5, 0, 1, 0, 0, 6, 0, 0, 1, 0])

# %%
kmeans.cluster_centers_[0:6]
# Out:
# array([[ 2.92996419e-01, -2.26784721e-01,  2.02688843e-01,
#          4.87847330e-01,  3.62343696e-01,  4.82145002e-01,
#         -5.20319324e-02,  2.99675191e-01,  2.17904367e-01,
#          5.39525413e-01,  5.46521036e-01,  2.11847694e-01,
#          1.20729661e-01,  1.10196885e-01,  5.02413622e-01,
#          2.31310889e-01, -4.08171521e-01],
#        [-3.72143791e-01, -5.68639250e+00, -4.54952639e-02,
#          2.57955833e-01,  7.94007771e-02,  3.86689125e-01,
#         -2.71827105e-01, -4.27701679e-02,  4.55807256e-02,
#          2.33871700e-01,  2.68579686e-01, -1.58495045e-01,
#          1.18946506e-01,  1.31795194e-01, -6.57546395e-02,
#          7.32936271e-01, -7.62180017e-01],
#        [ 1.75117575e+00, -1.02272727e-01,  7.03218237e-01,
#          2.43234818e-01,  1.80657034e+00,  1.14334070e+00,
#         -2.37013096e-02, -9.24413095e-02,  3.63996690e-01,
#          5.22321710e-01,  9.01785714e-01,  7.56696429e-01,
#          3.03024781e-01,  7.00995291e-01,  3.25861696e+01,
#          1.04166354e-02, -8.92857143e-02],
#        [-3.90657254e-01, -1.24632105e+00,  7.52370388e-01,
#          8.00367456e-01,  1.23262735e+00,  4.56579391e-02,
#          3.59560391e-01,  6.04211060e-01,  6.11021848e-01,
#          5.04202440e-02,  4.58081245e-02,  7.21261884e-01,
#          3.38040477e-01,  3.20081173e-01, -2.25001997e-01,
#          5.46505203e+00, -5.85998271e-01],
#        [ 2.45514420e+00, -4.12810367e-01,  2.61868409e+01,
#          3.95224449e+01,  1.16224267e+01,  9.10564870e-01,
#          4.80908670e-01,  2.53282955e+00,  7.05050000e-01,
#          1.87500051e-01,  4.65909091e-01,  7.44318182e+00,
#          2.62987013e+00,  1.79723290e+01,  4.52680226e+00,
#          3.66512062e+00, -9.09090909e-02],
#        [ 1.91571579e+00, -3.47066965e-01,  1.30921035e-01,
#          4.57890917e-01,  2.35031352e-01,  4.60636528e+00,
#         -2.40520448e-01,  1.92849421e-01,  4.48382397e-02,
#          2.22945951e+00,  3.89898990e+00,  7.79671717e-02,
#          9.20687393e-01,  2.03615207e+00,  1.98815687e+00,
#          3.07988358e-01, -6.55555556e-01]])

# %%
cluster_centers = pd.DataFrame(data=kmeans.cluster_centers_, 
                               columns = [df2.columns])
cluster_centers
# Out:
#     BALANCE BALANCE_FREQUENCY  PURCHASES ONEOFF_PURCHASES  \
# 0  0.292996         -0.226785   0.202689         0.487847
# 1 -0.372144         -5.686393  -0.045495         0.257956
# 2  1.751176         -0.102273   0.703218         0.243235
# 3 -0.390657         -1.246321   0.752370         0.800367
# 4  2.455144         -0.412810  26.186841        39.522445
# 5  1.915716         -0.347067   0.130921         0.457891
# 6  1.082686         -0.136858   4.919815         6.328490
#
#   INSTALLMENTS_PURCHASES CASH_ADVANCE PURCHASES_FREQUENCY  \
# 0               0.362344     0.482145           -0.052032
# 1               0.079401     0.386689           -0.271827
# 2               1.806570     1.143341           -0.023701
# 3               1.232627     0.045658            0.359560
# 4              11.622427     0.910565            0.480909
# 5               0.235031     4.606365           -0.240520
# 6               3.943065     0.555140            0.518675
#
#   ONEOFF_PURCHASES_FREQUENCY PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                   0.299675                         0.217904
# 1                  -0.042770                         0.045581
# 2                  -0.092441                         0.363997
# 3                   0.604211                         0.611022
# 4                   2.532830                         0.705050
# 5                   0.192849                         0.044838
# 6                   2.076400                         0.772465
#
#   CASH_ADVANCE_FREQUENCY CASH_ADVANCE_TRX PURCHASES_TRX CREDIT_LIMIT  \
# 0               0.539525         0.546521      0.211848     0.120730
# 1               0.233872         0.268580     -0.158495     0.118947
# 2               0.522322         0.901786      0.756696     0.303025
# 3               0.050420         0.045808      0.721262     0.338040
# 4               0.187500         0.465909      7.443182     2.629870
# 5               2.229460         3.898990      0.077967     0.920687
# 6               0.339350         0.470614      4.104276     1.072467
#
#     PAYMENTS MINIMUM_PAYMENTS PRC_FULL_PAYMENT    TENURE
# 0   0.110197         0.502414         0.231311 -0.408172
# 1   0.131795        -0.065755         0.732936 -0.762180
# 2   0.700995        32.586170         0.010417 -0.089286
# 3   0.320081        -0.225002         5.465052 -0.585998
# 4  17.972329         4.526802         3.665121 -0.090909
# 5   2.036152         1.988157         0.307988 -0.655556
# 6   2.879903         1.379672         1.561151 -0.078947

# %%
from sklearn import datasets
from sklearn.metrics import silhouette_score

# Fit the KMeans model
y_kmeans = kmeans.fit_predict(df_scaled)
# Calculate Silhoutte Score
score = silhouette_score(df_scaled, kmeans.labels_, metric='euclidean')
# Print the score
print('Silhouetter Average Score: %.3f' % score)
# Out:
# Silhouetter Average Score: 0.296

# %%
from yellowbrick.cluster import SilhouetteVisualizer

# Yellowbrick extends the Scikit-Learn API to make model selection and hyperparameter tuning easier.
# You can find the code to simply create Silhouette visualisation for K-Means clusters with n_cluster as 2, 3, 4, 5, 6, 7 below.

fig, ax = plt.subplots(3, 2, figsize=(13,8))
fig.suptitle('Silhouette Analysis for 2-7 Clusters', size = 18)
plt.tight_layout()

for i in [2, 3, 4, 5, 6, 7]:
    '''
    Create KMeans instance for different number of clusters
    '''
    km = KMeans(n_clusters=i, init='k-means++', n_init=10, max_iter=100, random_state=42)
    q, mod = divmod(i, 2)
    '''
    Create SilhouetteVisualizer instance with KMeans instance
    Fit the visualizer
    '''
    visualizer = SilhouetteVisualizer(km, colors='yellowbrick', ax=ax[q-1][mod])
    visualizer.fit(df_scaled)

# %% [markdown]
# dari shilouettescore ini dapat kita ketahui bahwa cluster ke 5 mendekati 6 lah yang lebih optimal, karna memiliki lebih sedikit distribusi yang mengarah ke nilai negatif.

# %% [markdown]
# # J. Evaluasi Model

# %% [markdown]
# Pada bagian ini, dilakukan evaluasi model yang harus menunjukkan bagaimana performa model berdasarkan metrics yang dipilih. Hal ini harus dibuktikan dengan visualisasi tren performa dan/atau tingkat kesalahan model.

# %% [markdown]
# K-MEANS CLUSTERING
# - Melihat Jumlah clusters yang optimal dengan menggunakan elbow method

# %%
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 0)
    kmeans.fit(df_scaled)
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 11), wcss, marker='o')
plt.title('The elbow method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') #within cluster sum of squares
plt.show()

# %% [markdown]
# - Melatih model KMeans dengan n_clusters sebanyak 4

# %%
kmeans = KMeans(n_clusters=4, init='k-means++', random_state=3)
kmeans.fit(df_scaled)
# Out:
# KMeans(n_clusters=4, random_state=3)

# %% [markdown]
# -  Menambahkan KMeans Segment pada dataframe

# %%
data_kmeans = df.copy()
data_kmeans['KMeans Segment'] = kmeans.labels_

# %% [markdown]
# - Melihat informasi data KMeans dengan melakukan groupby berdasarkan rata-rat KMeans segment

# %%
data_transf_kmeans = data_kmeans.groupby('KMeans Segment').mean()
data_transf_kmeans
# Out:
#                     BALANCE  BALANCE_FREQUENCY     PURCHASES  \
# KMeans Segment
# 0               5249.640708           0.959636  26813.470800
# 1               1428.414063           0.864624    506.080902
# 2               4324.419744           0.989214   1085.729492
# 3               2427.730075           0.973305   4452.903561
#
#                 ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# KMeans Segment
# 0                   21506.773200             5306.697600   1488.363253
# 1                     256.414814              249.920780    980.906286
# 2                     173.439322              912.290169   1416.709808
# 3                    2862.547668             1591.060725    921.438184
#
#                 PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# KMeans Segment
# 0                          0.912667                    0.845333
# 1                          0.437574                    0.145139
# 2                          0.493965                    0.057011
# 3                          0.917771                    0.671084
#
#                 PURCHASES_INSTALLMENTS_FREQUENCY  CASH_ADVANCE_FREQUENCY  \
# KMeans Segment
# 0                                       0.728667                0.056667
# 1                                       0.321101                0.141148
# 2                                       0.451207                0.132768
# 3                                       0.709747                0.087442
#
#                 CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT      PAYMENTS  \
# KMeans Segment
# 0                       2.400000     130.240000  15560.000000  27384.597243
# 1                       3.323856       8.996715   4062.613417   1284.582197
# 2                       4.050847      18.694915   4537.288136   2127.718119
# 3                       2.597689      58.922269   7791.071429   4763.974443
#
#                 MINIMUM_PAYMENTS  PRC_FULL_PAYMENT     TENURE
# KMeans Segment
# 0                    3148.432703          0.527424  11.920000
# 1                     672.644901          0.134205  11.470179
# 2                   22370.136257          0.002825  11.915254
# 3                    1063.852889          0.315436  11.873950

# %% [markdown]
# Dari hasil grouping segment KMeans, selanjutnya kami mencoba membuat kesimpulan tentang segment tersebut dan memberi nama pada segment tersebut.
#
# Disini Penarikan Tunai berkaitan dengan penggunaan kartu kredit dengan penarikan tunai yang biasanya dikenakan biaya dan memiliki tingkat bunga.

# %% [markdown]
# - Melakukan pemberian nama pada segment

# %%
data_transf_kmeans.rename({0:'Pengguna Level Tengah (Middle Ground)', 
                           1:'Penggua dengan Pembelian Kredit Tinggi (High Credit Frequent Purchasers)', 
                           2:'Pengguna dengan Penarikan Tunai Tinggi (High Cash Advance Users)', 
                           3:'Pengguna Kredit Hemat (Frugal Credit Users)'})
# Out:
#                                                         BALANCE  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)               5249.640708
# Penggua dengan Pembelian Kredit Tinggi (High Cr...  1428.414063
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...  4324.419744
# Pengguna Kredit Hemat (Frugal Credit Users)         2427.730075
#
#                                                     BALANCE_FREQUENCY  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                        0.959636
# Penggua dengan Pembelian Kredit Tinggi (High Cr...           0.864624
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...           0.989214
# Pengguna Kredit Hemat (Frugal Credit Users)                  0.973305
#
#                                                        PURCHASES  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)               26813.470800
# Penggua dengan Pembelian Kredit Tinggi (High Cr...    506.080902
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...   1085.729492
# Pengguna Kredit Hemat (Frugal Credit Users)          4452.903561
#
#                                                     ONEOFF_PURCHASES  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                   21506.773200
# Penggua dengan Pembelian Kredit Tinggi (High Cr...        256.414814
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...        173.439322
# Pengguna Kredit Hemat (Frugal Credit Users)              2862.547668
#
#                                                     INSTALLMENTS_PURCHASES  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                          5306.697600
# Penggua dengan Pembelian Kredit Tinggi (High Cr...              249.920780
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...              912.290169
# Pengguna Kredit Hemat (Frugal Credit Users)                    1591.060725
#
#                                                     CASH_ADVANCE  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                1488.363253
# Penggua dengan Pembelian Kredit Tinggi (High Cr...    980.906286
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...   1416.709808
# Pengguna Kredit Hemat (Frugal Credit Users)           921.438184
#
#                                                     PURCHASES_FREQUENCY  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                          0.912667
# Penggua dengan Pembelian Kredit Tinggi (High Cr...             0.437574
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...             0.493965
# Pengguna Kredit Hemat (Frugal Credit Users)                    0.917771
#
#                                                     ONEOFF_PURCHASES_FREQUENCY  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                                 0.845333
# Penggua dengan Pembelian Kredit Tinggi (High Cr...                    0.145139
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...                    0.057011
# Pengguna Kredit Hemat (Frugal Credit Users)                           0.671084
#
#                                                     PURCHASES_INSTALLMENTS_FREQUENCY  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                                       0.728667
# Penggua dengan Pembelian Kredit Tinggi (High Cr...                          0.321101
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...                          0.451207
# Pengguna Kredit Hemat (Frugal Credit Users)                                 0.709747
#
#                                                     CASH_ADVANCE_FREQUENCY  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                             0.056667
# Penggua dengan Pembelian Kredit Tinggi (High Cr...                0.141148
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...                0.132768
# Pengguna Kredit Hemat (Frugal Credit Users)                       0.087442
#
#                                                     CASH_ADVANCE_TRX  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                       2.400000
# Penggua dengan Pembelian Kredit Tinggi (High Cr...          3.323856
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...          4.050847
# Pengguna Kredit Hemat (Frugal Credit Users)                 2.597689
#
#                                                     PURCHASES_TRX  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                  130.240000
# Penggua dengan Pembelian Kredit Tinggi (High Cr...       8.996715
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...      18.694915
# Pengguna Kredit Hemat (Frugal Credit Users)             58.922269
#
#                                                     CREDIT_LIMIT  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)               15560.000000
# Penggua dengan Pembelian Kredit Tinggi (High Cr...   4062.613417
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...   4537.288136
# Pengguna Kredit Hemat (Frugal Credit Users)          7791.071429
#
#                                                         PAYMENTS  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)               27384.597243
# Penggua dengan Pembelian Kredit Tinggi (High Cr...   1284.582197
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...   2127.718119
# Pengguna Kredit Hemat (Frugal Credit Users)          4763.974443
#
#                                                     MINIMUM_PAYMENTS  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                    3148.432703
# Penggua dengan Pembelian Kredit Tinggi (High Cr...        672.644901
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...      22370.136257
# Pengguna Kredit Hemat (Frugal Credit Users)              1063.852889
#
#                                                     PRC_FULL_PAYMENT  \
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)                       0.527424
# Penggua dengan Pembelian Kredit Tinggi (High Cr...          0.134205
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...          0.002825
# Pengguna Kredit Hemat (Frugal Credit Users)                 0.315436
#
#                                                        TENURE
# KMeans Segment
# Pengguna Level Tengah (Middle Ground)               11.920000
# Penggua dengan Pembelian Kredit Tinggi (High Cr...  11.470179
# Pengguna dengan Penarikan Tunai Tinggi (High Ca...  11.915254
# Pengguna Kredit Hemat (Frugal Credit Users)         11.873950

# %% [markdown]
# - Memasukkan Label KMeans Segment ke dalam dataframe dengan membuat kolom baru

# %%
data_kmeans['Labels'] = data_kmeans['KMeans Segment'].map({0:'Pengguna Level Tengah (Middle Ground)', 
                                                           1:'Pengguna dengan Kredit Pembelian Tinggi (High Credit Frequent Purchasers)', 
                                                           2:'Pengguna dengan Penarikan Tunai Tinggi (High Cash Advance Users)', 
                                                           3:'Pengguna Kredit Hemat (Frugal Credit Users)'})

data_kmeans.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  KMeans Segment  \
# 0   201.802084        139.509787          0.000000      12               1
# 1  4103.032597       1072.340217          0.222222      12               1
# 2   622.066742        627.284787          0.000000      12               1
# 3     0.000000        864.206542          0.000000      12               1
# 4   678.334763        244.791237          0.000000      12               1
#
#                                               Labels
# 0  Pengguna dengan Kredit Pembelian Tinggi (High ...
# 1  Pengguna dengan Kredit Pembelian Tinggi (High ...
# 2  Pengguna dengan Kredit Pembelian Tinggi (High ...
# 3  Pengguna dengan Kredit Pembelian Tinggi (High ...
# 4  Pengguna dengan Kredit Pembelian Tinggi (High ...

# %% [markdown]
# Analisis Segment K-Means
#
# Disini dilakukan plotting atribut pada segment KMeans yang membagi data serta melihat perbedaan antara segmen pelanggan.

# %%
#sekarang kita dapat mengilustrasikan grup berdasarkan beberapa fitur dalam scatterplot

plt.figure(figsize=(14,10))
X = data_kmeans['PURCHASES_TRX']
Y = data_kmeans['PURCHASES']
g = sns.scatterplot(x=X, y=Y, hue = data_kmeans['Labels'], palette = 'rocket')
g.set_xlabel('Transaksi Pembelian')
g.set_ylabel('Pembelian per Akun')
g.set_title('Transaksi Pembelian vs Pembelian')
plt.show()

plt.savefig("Transaksi Pembelian vs Pembelian KMeans.png",
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')

# %%
plt.figure(figsize=(14,10))
X = data_kmeans['BALANCE']
Y = data_kmeans['PURCHASES']
g = sns.scatterplot(x=X, y=Y, hue = data_kmeans['Labels'], palette = 'rocket')
g.set_xlabel('Saldo Akun')
g.set_ylabel('Pembelian per Akun')
g.set_title('Saldo Akun vs Pembelian')
plt.show()

plt.savefig("Saldo Akun vs Pembelian KMeans.png",
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')

# %%
plt.figure(figsize=(14,10))
X = data_kmeans['PURCHASES_FREQUENCY']
Y = data_kmeans['PURCHASES_TRX']
g = sns.scatterplot(x=X, y=Y, hue = data_kmeans['Labels'], palette = 'rocket')
g.set_xlabel('Tingkat Frekuensi  Pembelian')
g.set_ylabel('Transaksi Pembelian')
g.set_title('Tingkat Frekuensi  Pembelian vs Transaksi Pembelian')
plt.show()

plt.savefig("Tingkat Frekuensi  Pembelian vs Transaksi Pembelian KMeans.png")

# %%
plt.figure(figsize=(14,10))
X = data_kmeans['CREDIT_LIMIT']
Y = data_kmeans['PURCHASES']
g = sns.scatterplot(x=X, y=Y, hue = data_kmeans['Labels'], palette = 'rocket')
g.set_xlabel('Batas Kredit Akun')
g.set_ylabel('Pembelian per Akun')
g.set_title('Batas Kredit Akun vs Pembelian per Akun')
plt.show()

plt.savefig("Batas Kredit Akun vs Pembelian per Akun KMeans.png",
            bbox_inches ="tight",
            pad_inches = 1,
            orientation ='landscape')

# %% [markdown]
# PCA (Principal Component Analysis)

# %%
pca = PCA()
pca
# Out:
# PCA()

# %%
principalComponents = pca.fit_transform(df_scaled)

# %% [markdown]
# - Melihat nilai variance ratio dari pca

# %%
pca.explained_variance_ratio_
# Out:
# array([3.07006673e-01, 2.19398406e-01, 1.27415073e-01, 8.47722617e-02,
#        7.33397573e-02, 5.58395398e-02, 3.43372493e-02, 2.75921597e-02,
#        2.12030154e-02, 1.56138249e-02, 1.16627738e-02, 9.05979478e-03,
#        5.04479469e-03, 4.09889568e-03, 3.38117030e-03, 2.33584081e-04,
#        1.02692480e-06])

# %% [markdown]
# - Visualisai Principal Components Variance untuk melihat nilai dari components beserta besarnya variance yang ditangkap

# %%
plt.figure(figsize=(12,10))
plt.plot(range(1, 18), pca.explained_variance_ratio_.cumsum(), marker='X', linestyle='--', )
plt.title('Variance PCA yang Ditangkap')
plt.xlabel('Principal Components')
plt.ylabel('Variance yang Ditangkap')
plt.show()

# %% [markdown]
# # UMAP Application

# %%
df.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE
# 0   201.802084        139.509787          0.000000      12
# 1  4103.032597       1072.340217          0.222222      12
# 2   622.066742        627.284787          0.000000      12
# 3     0.000000        864.206542          0.000000      12
# 4   678.334763        244.791237          0.000000      12

# %% [markdown]
# - Melakukan standarisasi pada dataset

# %%
scaler = StandardScaler()
Dfscaled = scaler.fit_transform(df2)
Dfscaled
# Out:
# array([[-0.73198937, -0.24943448, -0.42489974, ..., -0.31096755,
#         -0.52555097,  0.36067954],
#        [ 0.78696085,  0.13432467, -0.46955188, ...,  0.08931021,
#          0.2342269 ,  0.36067954],
#        [ 0.44713513,  0.51808382, -0.10766823, ..., -0.10166318,
#         -0.52555097,  0.36067954],
#        ...,
#        [-0.7403981 , -0.18547673, -0.40196519, ..., -0.33546549,
#          0.32919999, -4.12276757],
#        [-0.74517423, -0.18547673, -0.46955188, ..., -0.34690648,
#          0.32919999, -4.12276757],
#        [-0.57257511, -0.88903307,  0.04214581, ..., -0.33294642,
#         -0.52555097, -4.12276757]])

# %% [markdown]
# Kemudian kita akan Melakukan visualisasi untuk melihat 2 dimensi dari dataset yang sudah di standarisasi

# %% [markdown]
# - Mendefinisikan model dari UMAP

# %%
umap_data = UMAP(n_neighbors=100, 
                 n_components=2, # Untuk menganalisa jika bisa dilakukan split data pada 2 components
                 metric='euclidean', 
                 n_epochs=1000, 
                 learning_rate=0.1, #1.0
                 init='spectral',
                 min_dist=0.1, 
                 spread=1.0,
                 low_memory=False, 
                 set_op_mix_ratio=1.0,
                 local_connectivity=1,
                 repulsion_strength=1.0, 
                 negative_sample_rate=5, 
                 transform_queue_size=4.0, 
                 random_state=3,
                 angular_rp_forest=False,
                 target_n_neighbors=-1, 
                 transform_seed=3, 
                 verbose=False, 
                 unique=False,
                )

# %%
umap_data
# Out:
# UMAP(learning_rate=0.1, local_connectivity=1, low_memory=False, n_epochs=1000, n_neighbors=100, random_state=3, transform_seed=3)

# %% [markdown]
# - Melatih model dari UMAP data

# %%
umap_fit = umap_data.fit_transform(Dfscaled)
umap_fit
# Out:
# array([[6.764951 , 3.9201763],
#        [9.548963 , 7.808213 ],
#        [5.341515 , 8.939424 ],
#        ...,
#        [0.9345668, 3.0515974],
#        [9.28698  , 1.715428 ],
#        [8.886782 , 1.9776216]], dtype=float32)

# %% [markdown]
# - Melihat dimensi dari UMAP data

# %%
umap_fit.shape
# Out:
# (8950, 2)

# %% [markdown]
# - Menambahkan nilai UMAP pada dataframe dengan membuat kolom baru

# %%
data_umap = pd.concat([df, pd.DataFrame(umap_fit, columns=['UMAP1', 'UMAP2'])], axis=1)

# %%
data_umap.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE     UMAP1     UMAP2
# 0   201.802084        139.509787          0.000000      12  6.764951  3.920176
# 1  4103.032597       1072.340217          0.222222      12  9.548963  7.808213
# 2   622.066742        627.284787          0.000000      12  5.341515  8.939424
# 3     0.000000        864.206542          0.000000      12  6.219582  3.107923
# 4   678.334763        244.791237          0.000000      12  7.498124  4.461841

# %% [markdown]
# - Melihat dimensi dataframe (opsional)

# %%
data_umap.shape
# Out:
# (8950, 20)

# %% [markdown]
# - Melihat apakah terdapat missing value pada UMAP data

# %%
data_umap.isnull().any()
# Out:
# CUST_ID                             False
# BALANCE                             False
# BALANCE_FREQUENCY                   False
# PURCHASES                           False
# ONEOFF_PURCHASES                    False
# INSTALLMENTS_PURCHASES              False
# CASH_ADVANCE                        False
# PURCHASES_FREQUENCY                 False
# ONEOFF_PURCHASES_FREQUENCY          False
# PURCHASES_INSTALLMENTS_FREQUENCY    False
# CASH_ADVANCE_FREQUENCY              False
# CASH_ADVANCE_TRX                    False
# PURCHASES_TRX                       False
# CREDIT_LIMIT                        False
# PAYMENTS                            False
# MINIMUM_PAYMENTS                    False
# PRC_FULL_PAYMENT                    False
# TENURE                              False
# UMAP1                               False
# UMAP2                               False
# dtype: bool

# %% [markdown]
# - Menerapkan kembali K-Means ke data yang dikembalikan dari penerapan UMAP yang hanya dengan 2 komponen.

# %%
wcss = []
for i in range(1, 18):
    kmeans_pca = KMeans(n_clusters=i, init='k-means++', random_state=3)
    kmeans_pca.fit(umap_fit)
    wcss.append(kmeans_pca.inertia_)

# %% [markdown]
# - Membuat visualisasi jumlah cluster KMeans dengan UMAP Data

# %%
plt.figure(figsize=(16,10))
plt.plot(range(1, 18), wcss, marker='X', linestyle='-.')
plt.xlabel('Jumlah Cluster')
plt.ylabel('WCSS Score')
plt.title('K-Means dengan UMAP Data')
plt.show()

# %% [markdown]
# Dengan menggunakan K-Means pada data UMAP, didapatkan jumlah cluster yang optimal yaitu 4 berdasarkan plot Scree. Namun, dengan menggunakan 4 cluster diperoleh score WCSS yang jauh lebih rendah daripada ketika diterapkan pada komponen PCA.

# %% [markdown]
# - Melatih KMeans UMAP dengan n_clusters = 4

# %%
kmeans_umap = KMeans(n_clusters=4, init='k-means++', random_state=42)
kmeans_umap.fit(umap_fit)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %% [markdown]
# - Memasukan hasil KMeans UMAP segmen ke dalam dataframe

# %%
data_umap_kmeans = pd.concat([df.reset_index(drop=True), pd.DataFrame(umap_fit)], axis=1)
data_umap_kmeans.columns.values[-2:] = ['UMAP1', 'UMAP2']

data_umap_kmeans['K-Means UMAP Segment'] = kmeans_umap.labels_
data_umap_kmeans
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                      95.40      0.000000             0.166667
# 1                       0.00   6442.945483             0.000000
# 2                       0.00      0.000000             1.000000
# 3                       0.00    205.788017             0.083333
# 4                       0.00      0.000000             0.083333
# ...                      ...           ...                  ...
# 8945                  291.12      0.000000             1.000000
# 8946                  300.00      0.000000             1.000000
# 8947                  144.40      0.000000             0.833333
# 8948                    0.00     36.558778             0.000000
# 8949                    0.00    127.040008             0.666667
#
#       ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                       0.000000                          0.083333  ...
# 1                       0.000000                          0.000000  ...
# 2                       1.000000                          0.000000  ...
# 3                       0.083333                          0.000000  ...
# 4                       0.083333                          0.000000  ...
# ...                          ...                               ...  ...
# 8945                    0.000000                          0.833333  ...
# 8946                    0.000000                          0.833333  ...
# 8947                    0.000000                          0.666667  ...
# 8948                    0.000000                          0.000000  ...
# 8949                    0.666667                          0.000000  ...
#
#       CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT     PAYMENTS  \
# 0                    0              2        1000.0   201.802084
# 1                    4              0        7000.0  4103.032597
# 2                    0             12        7500.0   622.066742
# 3                    1              1        7500.0     0.000000
# 4                    0              1        1200.0   678.334763
# ...                ...            ...           ...          ...
# 8945                 0              6        1000.0   325.594462
# 8946                 0              6        1000.0   275.861322
# 8947                 0              5        1000.0    81.270775
# 8948                 2              0         500.0    52.549959
# 8949                 2             23        1200.0    63.165404
#
#       MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE     UMAP1     UMAP2  \
# 0           139.509787          0.000000      12  6.764951  3.920176
# 1          1072.340217          0.222222      12  9.548963  7.808213
# 2           627.284787          0.000000      12  5.341515  8.939424
# 3           864.206542          0.000000      12  6.219582  3.107923
# 4           244.791237          0.000000      12  7.498124  4.461841
# ...                ...               ...     ...       ...       ...
# 8945         48.886365          0.500000       6  0.863442  3.286420
# 8946        864.206542          0.000000       6  0.960278  2.897826
# 8947         82.418369          0.250000       6  0.934567  3.051597
# 8948         55.755628          0.250000       6  9.286980  1.715428
# 8949         88.288956          0.000000       6  8.886782  1.977622
#
#       K-Means UMAP Segment
# 0                        1
# 1                        2
# 2                        0
# 3                        1
# 4                        1
# ...                    ...
# 8945                     3
# 8946                     3
# 8947                     3
# 8948                     1
# 8949                     1
#
# [8950 rows x 21 columns]

# %% [markdown]
# - Melihat persebaran data pada masing-masing cluster (K-Means UMAP Segment)

# %%
data_umap_kmeans['K-Means UMAP Segment'].value_counts()
# Out:
# 2    2785
# 0    2758
# 1    1913
# 3    1494
# Name: K-Means UMAP Segment, dtype: int64

# %% [markdown]
# - Melihat frekuensi rata-rata KMeans UMA Segment dengan melakukan grouping

# %%
umap_kmeans_freq = data_umap_kmeans.groupby(['K-Means UMAP Segment']).mean()
umap_kmeans_freq
# Out:
#                           BALANCE  BALANCE_FREQUENCY    PURCHASES  \
# K-Means UMAP Segment
# 0                     1703.086510           0.982591  2383.398426
# 1                      675.275271           0.646135   322.270256
# 2                     2802.773013           0.983363   337.649131
# 3                      138.830442           0.781032   567.881238
#
#                       ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  CASH_ADVANCE  \
# K-Means UMAP Segment
# 0                          1441.815928              941.945660    404.493202
# 1                           248.568761               73.881213    740.931012
# 2                           257.578722               80.267734   2183.798674
# 3                            88.967443              479.443701     97.740208
#
#                       PURCHASES_FREQUENCY  ONEOFF_PURCHASES_FREQUENCY  \
# K-Means UMAP Segment
# 0                                0.867603                    0.455731
# 1                                0.194083                    0.099549
# 2                                0.165234                    0.104614
# 3                                0.779337                    0.049065
#
#                       PURCHASES_INSTALLMENTS_FREQUENCY  \
# K-Means UMAP Segment
# 0                                             0.652309
# 1                                             0.096356
# 2                                             0.076572
# 3                                             0.712893
#
#                       CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  \
# K-Means UMAP Segment
# 0                                   0.068170          1.445613      34.627991
# 1                                   0.101286          1.866179       3.326189
# 2                                   0.286446          7.544704       4.164811
# 3                                   0.020090          0.340027      12.173360
#
#                       CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  \
# K-Means UMAP Segment
# 0                      5369.147604  2461.717544       1382.524426
# 1                      3361.253415  1041.086829        394.200413
# 2                      5149.199717  2041.009370       1026.427828
# 3                      3110.183732   700.408493        206.786678
#
#                       PRC_FULL_PAYMENT     TENURE     UMAP1     UMAP2
# K-Means UMAP Segment
# 0                             0.171097  11.941262  4.347188  7.662092
# 1                             0.047390  10.745949  7.177538  2.962480
# 2                             0.026324  11.878276  9.307920  6.915232
# 3                             0.495242  11.049531  2.730431  4.162434

# %% [markdown]
# - Memberikan nama label pada cluster seperti sebelumnya dan menjelajahi beberapa variabel dengan cluster yang dihasilkan dengan segmen UMAP

# %%
data_umap_kmeans['Labels'] = data_umap_kmeans['K-Means UMAP Segment'].map({0:'Pengguna yang Bergantung Pada Uang Muka', 
                                                                           1:'Pengguna dengan Pembelian dan Kredit Besar', 
                                                                           2:'Pengguna Normal (Standard)', 
                                                                           3:'Pengguna dengan Cicilan Pembelian dan Minimal Kredit'})

# %%
data_umap_kmeans.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  ...  \
# 0                    0.000000                          0.083333  ...
# 1                    0.000000                          0.000000  ...
# 2                    1.000000                          0.000000  ...
# 3                    0.083333                          0.000000  ...
# 4                    0.083333                          0.000000  ...
#
#    PURCHASES_TRX  CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  \
# 0              2        1000.0   201.802084        139.509787
# 1              0        7000.0  4103.032597       1072.340217
# 2             12        7500.0   622.066742        627.284787
# 3              1        7500.0     0.000000        864.206542
# 4              1        1200.0   678.334763        244.791237
#
#    PRC_FULL_PAYMENT  TENURE     UMAP1     UMAP2  K-Means UMAP Segment  \
# 0          0.000000      12  6.764951  3.920176                     1
# 1          0.222222      12  9.548963  7.808213                     2
# 2          0.000000      12  5.341515  8.939424                     0
# 3          0.000000      12  6.219582  3.107923                     1
# 4          0.000000      12  7.498124  4.461841                     1
#
#                                        Labels
# 0  Pengguna dengan Pembelian dan Kredit Besar
# 1                  Pengguna Normal (Standard)
# 2     Pengguna yang Bergantung Pada Uang Muka
# 3  Pengguna dengan Pembelian dan Kredit Besar
# 4  Pengguna dengan Pembelian dan Kredit Besar
#
# [5 rows x 22 columns]

# %% [markdown]
# - Melakukan eksplorasi pada UMAP K-Means Clusters

# %%
plt.figure(figsize=(14,10))
X = data_umap_kmeans['CASH_ADVANCE']
Y = data_umap_kmeans['INSTALLMENTS_PURCHASES']
g = sns.scatterplot(x=X, y=Y, hue = data_umap_kmeans['Labels'], palette = 'Spectral')
g.set_xlabel('Penarikan Tunai')
g.set_ylabel('Pembelian Angsuran')
g.set_title('Penarikan Tunai vs Pembelian Angsuran')
plt.show()

plt.savefig("Penarikan Tunai vs Pembelian Angsuran UMAP.png",
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')

# %%
plt.figure(figsize=(14,10))
X = data_umap_kmeans['PURCHASES']
Y = data_umap_kmeans['PAYMENTS']
g = sns.scatterplot(x=X, y=Y, hue = data_umap_kmeans['Labels'], palette = 'Spectral')
g.set_xlabel('Pembelian')
g.set_ylabel('Pembayaran')
g.set_title('Pembelian vs Pembayaran')

plt.show()

plt.savefig("Pembelian vs Pembayaran UMAP.png",
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')

# %%
plt.figure(figsize=(14,10))
X = data_umap_kmeans['ONEOFF_PURCHASES']
Y = data_umap_kmeans['CREDIT_LIMIT']
g = sns.scatterplot(x=X, y=Y, hue = data_umap_kmeans['Labels'], palette = 'Spectral')
g.set_xlabel('Pembelian Satu Kali (one off)')
g.set_ylabel('Batas Kredit')
g.set_title('Pembelian Satu Kali (one off) vs Batas Kredit')

plt.show()

plt.savefig("Pembelian Satu Kali (one off) vs Batas Kredit UMAP.png",
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')

# %%
plt.figure(figsize=(14,10))
X = data_umap_kmeans['BALANCE']
Y = data_umap_kmeans['MINIMUM_PAYMENTS']
g = sns.scatterplot(x=X, y=Y, hue = data_umap_kmeans['Labels'], palette = 'Spectral')
g.set_xlabel('Saldo')
g.set_ylabel('Minimal / Minimum Pembayaran')
g.set_title('Saldo vs Minimal / Minimum Pembayaran')

plt.show()

plt.savefig("Saldo vs Minimum Pembayaran UMAP.png",
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')

# %% [markdown]
# - Membuat pie chart yang sama dengan data yang menggunakan PCA untuk memvisualisasikan Jumlah Pengamatan per Segment

# %%
umap_kmeans_freq['JumlahPengamatan'] = data_umap_kmeans[['K-Means UMAP Segment', 'BALANCE']].groupby(['K-Means UMAP Segment']).count()
umap_kmeans_freq['ProporsiPengamatan'] = umap_kmeans_freq['JumlahPengamatan'] / umap_kmeans_freq['JumlahPengamatan'].sum()
umap_kmeans_freq = umap_kmeans_freq.rename({0:'Pengguna yang Bergantung Pada Uang Muka', 
                                            1:'Pengguna dengan Pembelian dan Kredit Besar',
                                            2:'Pengguna Normal (Standard)',
                                            3:'Pengguna dengan Cicilan Pembelian dan Minimal Kredit'})
umap_kmeans_freq
# Out:
#                                                         BALANCE  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka             1703.086510
# Pengguna dengan Pembelian dan Kredit Besar           675.275271
# Pengguna Normal (Standard)                          2802.773013
# Pengguna dengan Cicilan Pembelian dan Minimal K...   138.830442
#
#                                                     BALANCE_FREQUENCY  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                      0.982591
# Pengguna dengan Pembelian dan Kredit Besar                   0.646135
# Pengguna Normal (Standard)                                   0.983363
# Pengguna dengan Cicilan Pembelian dan Minimal K...           0.781032
#
#                                                       PURCHASES  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka             2383.398426
# Pengguna dengan Pembelian dan Kredit Besar           322.270256
# Pengguna Normal (Standard)                           337.649131
# Pengguna dengan Cicilan Pembelian dan Minimal K...   567.881238
#
#                                                     ONEOFF_PURCHASES  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                  1441.815928
# Pengguna dengan Pembelian dan Kredit Besar                248.568761
# Pengguna Normal (Standard)                                257.578722
# Pengguna dengan Cicilan Pembelian dan Minimal K...         88.967443
#
#                                                     INSTALLMENTS_PURCHASES  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                         941.945660
# Pengguna dengan Pembelian dan Kredit Besar                       73.881213
# Pengguna Normal (Standard)                                       80.267734
# Pengguna dengan Cicilan Pembelian dan Minimal K...              479.443701
#
#                                                     CASH_ADVANCE  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka               404.493202
# Pengguna dengan Pembelian dan Kredit Besar            740.931012
# Pengguna Normal (Standard)                           2183.798674
# Pengguna dengan Cicilan Pembelian dan Minimal K...     97.740208
#
#                                                     PURCHASES_FREQUENCY  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                        0.867603
# Pengguna dengan Pembelian dan Kredit Besar                     0.194083
# Pengguna Normal (Standard)                                     0.165234
# Pengguna dengan Cicilan Pembelian dan Minimal K...             0.779337
#
#                                                     ONEOFF_PURCHASES_FREQUENCY  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                               0.455731
# Pengguna dengan Pembelian dan Kredit Besar                            0.099549
# Pengguna Normal (Standard)                                            0.104614
# Pengguna dengan Cicilan Pembelian dan Minimal K...                    0.049065
#
#                                                     PURCHASES_INSTALLMENTS_FREQUENCY  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                                     0.652309
# Pengguna dengan Pembelian dan Kredit Besar                                  0.096356
# Pengguna Normal (Standard)                                                  0.076572
# Pengguna dengan Cicilan Pembelian dan Minimal K...                          0.712893
#
#                                                     CASH_ADVANCE_FREQUENCY  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                           0.068170
# Pengguna dengan Pembelian dan Kredit Besar                        0.101286
# Pengguna Normal (Standard)                                        0.286446
# Pengguna dengan Cicilan Pembelian dan Minimal K...                0.020090
#
#                                                     ...  PURCHASES_TRX  \
# K-Means UMAP Segment                                ...
# Pengguna yang Bergantung Pada Uang Muka             ...      34.627991
# Pengguna dengan Pembelian dan Kredit Besar          ...       3.326189
# Pengguna Normal (Standard)                          ...       4.164811
# Pengguna dengan Cicilan Pembelian dan Minimal K...  ...      12.173360
#
#                                                     CREDIT_LIMIT     PAYMENTS  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka              5369.147604  2461.717544
# Pengguna dengan Pembelian dan Kredit Besar           3361.253415  1041.086829
# Pengguna Normal (Standard)                           5149.199717  2041.009370
# Pengguna dengan Cicilan Pembelian dan Minimal K...   3110.183732   700.408493
#
#                                                     MINIMUM_PAYMENTS  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                  1382.524426
# Pengguna dengan Pembelian dan Kredit Besar                394.200413
# Pengguna Normal (Standard)                               1026.427828
# Pengguna dengan Cicilan Pembelian dan Minimal K...        206.786678
#
#                                                     PRC_FULL_PAYMENT  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                     0.171097
# Pengguna dengan Pembelian dan Kredit Besar                  0.047390
# Pengguna Normal (Standard)                                  0.026324
# Pengguna dengan Cicilan Pembelian dan Minimal K...          0.495242
#
#                                                        TENURE     UMAP1  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka             11.941262  4.347188
# Pengguna dengan Pembelian dan Kredit Besar          10.745949  7.177538
# Pengguna Normal (Standard)                          11.878276  9.307920
# Pengguna dengan Cicilan Pembelian dan Minimal K...  11.049531  2.730431
#
#                                                        UMAP2  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka             7.662092
# Pengguna dengan Pembelian dan Kredit Besar          2.962480
# Pengguna Normal (Standard)                          6.915232
# Pengguna dengan Cicilan Pembelian dan Minimal K...  4.162434
#
#                                                     JumlahPengamatan  \
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                         2758
# Pengguna dengan Pembelian dan Kredit Besar                      1913
# Pengguna Normal (Standard)                                      2785
# Pengguna dengan Cicilan Pembelian dan Minimal K...              1494
#
#                                                     ProporsiPengamatan
# K-Means UMAP Segment
# Pengguna yang Bergantung Pada Uang Muka                       0.308156
# Pengguna dengan Pembelian dan Kredit Besar                    0.213743
# Pengguna Normal (Standard)                                    0.311173
# Pengguna dengan Cicilan Pembelian dan Minimal K...            0.166927
#
# [4 rows x 21 columns]

# %%
umap_kmeans_freq.plot.pie(y='JumlahPengamatan', figsize=(6, 6), autopct='%1.0f%%', cmap = 'Spectral')
plt.ylabel(None, loc='center')
plt.legend(loc='center right')
plt.title('Jumlah Pengamatan per Segment')
plt.show()

plt.savefig("Jumlah Pengamatan per Segment UMAP.png",
            bbox_inches ="tight",
            pad_inches = 1,
            transparent = True,
            orientation ='landscape')

# %% [markdown]
# # K. Model Inference

# %% [markdown]
# Bagian ini diisi dengan model inference, di mana model yang sudah kita latih akan dicoba pada data selain data yang sudah tersedia.

# %%
# Concatenate the clusters labels to our original dataframe
df_cluster = pd.concat([df, pd.DataFrame({'cluster':labels})], axis = 1)
df_cluster.head()
# Out:
#   CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0  C10001    40.900749           0.818182      95.40              0.00
# 1  C10002  3202.467416           0.909091       0.00              0.00
# 2  C10003  2495.148862           1.000000     773.17            773.17
# 3  C10004  1666.670542           0.636364    1499.00           1499.00
# 4  C10005   817.714335           1.000000      16.00             16.00
#
#    INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# 0                    95.4      0.000000             0.166667
# 1                     0.0   6442.945483             0.000000
# 2                     0.0      0.000000             1.000000
# 3                     0.0    205.788017             0.083333
# 4                     0.0      0.000000             0.083333
#
#    ONEOFF_PURCHASES_FREQUENCY  PURCHASES_INSTALLMENTS_FREQUENCY  \
# 0                    0.000000                          0.083333
# 1                    0.000000                          0.000000
# 2                    1.000000                          0.000000
# 3                    0.083333                          0.000000
# 4                    0.083333                          0.000000
#
#    CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  PURCHASES_TRX  CREDIT_LIMIT  \
# 0                0.000000                 0              2        1000.0
# 1                0.250000                 4              0        7000.0
# 2                0.000000                 0             12        7500.0
# 3                0.083333                 1              1        7500.0
# 4                0.000000                 0              1        1200.0
#
#       PAYMENTS  MINIMUM_PAYMENTS  PRC_FULL_PAYMENT  TENURE  cluster
# 0   201.802084        139.509787          0.000000      12        0
# 1  4103.032597       1072.340217          0.222222      12        5
# 2   622.066742        627.284787          0.000000      12        0
# 3     0.000000        864.206542          0.000000      12        1
# 4   678.334763        244.791237          0.000000      12        0

# %%
df_cluster.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8950 entries, 0 to 8949
# Data columns (total 19 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   CUST_ID                           8950 non-null   object
#  1   BALANCE                           8950 non-null   float64
#  2   BALANCE_FREQUENCY                 8950 non-null   float64
#  3   PURCHASES                         8950 non-null   float64
#  4   ONEOFF_PURCHASES                  8950 non-null   float64
#  5   INSTALLMENTS_PURCHASES            8950 non-null   float64
#  6   CASH_ADVANCE                      8950 non-null   float64
#  7   PURCHASES_FREQUENCY               8950 non-null   float64
#  8   ONEOFF_PURCHASES_FREQUENCY        8950 non-null   float64
#  9   PURCHASES_INSTALLMENTS_FREQUENCY  8950 non-null   float64
#  10  CASH_ADVANCE_FREQUENCY            8950 non-null   float64
#  11  CASH_ADVANCE_TRX                  8950 non-null   int64
#  12  PURCHASES_TRX                     8950 non-null   int64
#  13  CREDIT_LIMIT                      8950 non-null   float64
#  14  PAYMENTS                          8950 non-null   float64
#  15  MINIMUM_PAYMENTS                  8950 non-null   float64
#  16  PRC_FULL_PAYMENT                  8950 non-null   float64
#  17  TENURE                            8950 non-null   int64
#  18  cluster                           8950 non-null   int32
# dtypes: float64(14), int32(1), int64(3), object(1)
# memory usage: 1.3+ MB

# %% [markdown]
# Menghapus kolom yang tidak diperlukan

# %%
drop_cols = ['BALANCE_FREQUENCY', 'PURCHASES_FREQUENCY', 'ONEOFF_PURCHASES_FREQUENCY', 'PURCHASES_INSTALLMENTS_FREQUENCY', 
             'CASH_ADVANCE_FREQUENCY', 'PURCHASES_TRX', 'PURCHASES_TRX', 'CASH_ADVANCE_TRX']

# %%
data = df.drop(drop_cols, axis=1)
data.head()
# Out:
#   CUST_ID      BALANCE  PURCHASES  ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# 0  C10001    40.900749      95.40              0.00                    95.4
# 1  C10002  3202.467416       0.00              0.00                     0.0
# 2  C10003  2495.148862     773.17            773.17                     0.0
# 3  C10004  1666.670542    1499.00           1499.00                     0.0
# 4  C10005   817.714335      16.00             16.00                     0.0
#
#    CASH_ADVANCE  CREDIT_LIMIT     PAYMENTS  MINIMUM_PAYMENTS  \
# 0      0.000000        1000.0   201.802084        139.509787
# 1   6442.945483        7000.0  4103.032597       1072.340217
# 2      0.000000        7500.0   622.066742        627.284787
# 3    205.788017        7500.0     0.000000        864.206542
# 4      0.000000        1200.0   678.334763        244.791237
#
#    PRC_FULL_PAYMENT  TENURE
# 0          0.000000      12
# 1          0.222222      12
# 2          0.000000      12
# 3          0.000000      12
# 4          0.000000      12

# %%
df.corr()
# Out:
#                                    BALANCE  BALANCE_FREQUENCY  PURCHASES  \
# BALANCE                           1.000000           0.322412   0.181261
# BALANCE_FREQUENCY                 0.322412           1.000000   0.133674
# PURCHASES                         0.181261           0.133674   1.000000
# ONEOFF_PURCHASES                  0.164350           0.104323   0.916845
# INSTALLMENTS_PURCHASES            0.126469           0.124292   0.679896
# CASH_ADVANCE                      0.496692           0.099388  -0.051474
# PURCHASES_FREQUENCY              -0.077944           0.229715   0.393017
# ONEOFF_PURCHASES_FREQUENCY        0.073166           0.202415   0.498430
# PURCHASES_INSTALLMENTS_FREQUENCY -0.063186           0.176079   0.315567
# CASH_ADVANCE_FREQUENCY            0.449218           0.191873  -0.120143
# CASH_ADVANCE_TRX                  0.385152           0.141555  -0.067175
# PURCHASES_TRX                     0.154338           0.189626   0.689561
# CREDIT_LIMIT                      0.531267           0.095795   0.356959
# PAYMENTS                          0.322802           0.065008   0.603264
# MINIMUM_PAYMENTS                  0.394282           0.114249   0.093515
# PRC_FULL_PAYMENT                 -0.318959          -0.095082   0.180379
# TENURE                            0.072692           0.119776   0.086288
#
#                                   ONEOFF_PURCHASES  INSTALLMENTS_PURCHASES  \
# BALANCE                                   0.164350                0.126469
# BALANCE_FREQUENCY                         0.104323                0.124292
# PURCHASES                                 0.916845                0.679896
# ONEOFF_PURCHASES                          1.000000                0.330622
# INSTALLMENTS_PURCHASES                    0.330622                1.000000
# CASH_ADVANCE                             -0.031326               -0.064244
# PURCHASES_FREQUENCY                       0.264937                0.442418
# ONEOFF_PURCHASES_FREQUENCY                0.524891                0.214042
# PURCHASES_INSTALLMENTS_FREQUENCY          0.127729                0.511351
# CASH_ADVANCE_FREQUENCY                   -0.082628               -0.132318
# CASH_ADVANCE_TRX                         -0.046212               -0.073999
# PURCHASES_TRX                             0.545523                0.628108
# CREDIT_LIMIT                              0.319721                0.256496
# PAYMENTS                                  0.567292                0.384084
# MINIMUM_PAYMENTS                          0.048597                0.131687
# PRC_FULL_PAYMENT                          0.132763                0.182569
# TENURE                                    0.064150                0.086143
#
#                                   CASH_ADVANCE  PURCHASES_FREQUENCY  \
# BALANCE                               0.496692            -0.077944
# BALANCE_FREQUENCY                     0.099388             0.229715
# PURCHASES                            -0.051474             0.393017
# ONEOFF_PURCHASES                     -0.031326             0.264937
# INSTALLMENTS_PURCHASES               -0.064244             0.442418
# CASH_ADVANCE                          1.000000            -0.215507
# PURCHASES_FREQUENCY                  -0.215507             1.000000
# ONEOFF_PURCHASES_FREQUENCY           -0.086754             0.501343
# PURCHASES_INSTALLMENTS_FREQUENCY     -0.177070             0.862934
# CASH_ADVANCE_FREQUENCY                0.628522            -0.308478
# CASH_ADVANCE_TRX                      0.656498            -0.203478
# PURCHASES_TRX                        -0.075850             0.568430
# CREDIT_LIMIT                          0.303983             0.119778
# PAYMENTS                              0.453238             0.103464
# MINIMUM_PAYMENTS                      0.139223             0.002976
# PRC_FULL_PAYMENT                     -0.152935             0.305802
# TENURE                               -0.068312             0.061506
#
#                                   ONEOFF_PURCHASES_FREQUENCY  \
# BALANCE                                             0.073166
# BALANCE_FREQUENCY                                   0.202415
# PURCHASES                                           0.498430
# ONEOFF_PURCHASES                                    0.524891
# INSTALLMENTS_PURCHASES                              0.214042
# CASH_ADVANCE                                       -0.086754
# PURCHASES_FREQUENCY                                 0.501343
# ONEOFF_PURCHASES_FREQUENCY                          1.000000
# PURCHASES_INSTALLMENTS_FREQUENCY                    0.142329
# CASH_ADVANCE_FREQUENCY                             -0.111716
# CASH_ADVANCE_TRX                                   -0.069088
# PURCHASES_TRX                                       0.544869
# CREDIT_LIMIT                                        0.295030
# PAYMENTS                                            0.243537
# MINIMUM_PAYMENTS                                   -0.029963
# PRC_FULL_PAYMENT                                    0.157531
# TENURE                                              0.082466
#
#                                   PURCHASES_INSTALLMENTS_FREQUENCY  \
# BALANCE                                                  -0.063186
# BALANCE_FREQUENCY                                         0.176079
# PURCHASES                                                 0.315567
# ONEOFF_PURCHASES                                          0.127729
# INSTALLMENTS_PURCHASES                                    0.511351
# CASH_ADVANCE                                             -0.177070
# PURCHASES_FREQUENCY                                       0.862934
# ONEOFF_PURCHASES_FREQUENCY                                0.142329
# PURCHASES_INSTALLMENTS_FREQUENCY                          1.000000
# CASH_ADVANCE_FREQUENCY                                   -0.262958
# CASH_ADVANCE_TRX                                         -0.169207
# PURCHASES_TRX                                             0.529975
# CREDIT_LIMIT                                              0.060752
# PAYMENTS                                                  0.085551
# MINIMUM_PAYMENTS                                          0.029590
# PRC_FULL_PAYMENT                                          0.250087
# TENURE                                                    0.073275
#
#                                   CASH_ADVANCE_FREQUENCY  CASH_ADVANCE_TRX  \
# BALANCE                                         0.449218          0.385152
# BALANCE_FREQUENCY                               0.191873          0.141555
# PURCHASES                                      -0.120143         -0.067175
# ONEOFF_PURCHASES                               -0.082628         -0.046212
# INSTALLMENTS_PURCHASES                         -0.132318         -0.073999
# CASH_ADVANCE                                    0.628522          0.656498
# PURCHASES_FREQUENCY                            -0.308478         -0.203478
# ONEOFF_PURCHASES_FREQUENCY                     -0.111716         -0.069088
# PURCHASES_INSTALLMENTS_FREQUENCY               -0.262958         -0.169207
# CASH_ADVANCE_FREQUENCY                          1.000000          0.799561
# CASH_ADVANCE_TRX                                0.799561          1.000000
# PURCHASES_TRX                                  -0.131168         -0.066157
# CREDIT_LIMIT                                    0.132616          0.149699
# PAYMENTS                                        0.183192          0.255278
# MINIMUM_PAYMENTS                                0.097898          0.109185
# PRC_FULL_PAYMENT                               -0.249773         -0.169784
# TENURE                                         -0.133372         -0.043421
#
#                                   PURCHASES_TRX  CREDIT_LIMIT  PAYMENTS  \
# BALANCE                                0.154338      0.531267  0.322802
# BALANCE_FREQUENCY                      0.189626      0.095795  0.065008
# PURCHASES                              0.689561      0.356959  0.603264
# ONEOFF_PURCHASES                       0.545523      0.319721  0.567292
# INSTALLMENTS_PURCHASES                 0.628108      0.256496  0.384084
# CASH_ADVANCE                          -0.075850      0.303983  0.453238
# PURCHASES_FREQUENCY                    0.568430      0.119778  0.103464
# ONEOFF_PURCHASES_FREQUENCY             0.544869      0.295030  0.243537
# PURCHASES_INSTALLMENTS_FREQUENCY       0.529975      0.060752  0.085551
# CASH_ADVANCE_FREQUENCY                -0.131168      0.132616  0.183192
# CASH_ADVANCE_TRX                      -0.066157      0.149699  0.255278
# PURCHASES_TRX                          1.000000      0.272877  0.370832
# CREDIT_LIMIT                           0.272877      1.000000  0.421852
# PAYMENTS                               0.370832      0.421852  1.000000
# MINIMUM_PAYMENTS                       0.095858      0.125134  0.125046
# PRC_FULL_PAYMENT                       0.162066      0.055671  0.112138
# TENURE                                 0.121874      0.139034  0.106136
#
#                                   MINIMUM_PAYMENTS  PRC_FULL_PAYMENT    TENURE
# BALANCE                                   0.394282         -0.318959  0.072692
# BALANCE_FREQUENCY                         0.114249         -0.095082  0.119776
# PURCHASES                                 0.093515          0.180379  0.086288
# ONEOFF_PURCHASES                          0.048597          0.132763  0.064150
# INSTALLMENTS_PURCHASES                    0.131687          0.182569  0.086143
# CASH_ADVANCE                              0.139223         -0.152935 -0.068312
# PURCHASES_FREQUENCY                       0.002976          0.305802  0.061506
# ONEOFF_PURCHASES_FREQUENCY               -0.029963          0.157531  0.082466
# PURCHASES_INSTALLMENTS_FREQUENCY          0.029590          0.250087  0.073275
# CASH_ADVANCE_FREQUENCY                    0.097898         -0.249773 -0.133372
# CASH_ADVANCE_TRX                          0.109185         -0.169784 -0.043421
# PURCHASES_TRX                             0.095858          0.162066  0.121874
# CREDIT_LIMIT                              0.125134          0.055671  0.139034
# PAYMENTS                                  0.125046          0.112138  0.106136
# MINIMUM_PAYMENTS                          1.000000         -0.139674  0.057257
# PRC_FULL_PAYMENT                         -0.139674          1.000000 -0.016486
# TENURE                                    0.057257         -0.016486  1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(df.corr(), annot=True)
plt.savefig('corr_matrix.png')

# %% [markdown]
# Melakukan inisialisasi variabel X dan Y

# %%
X = data.drop(['CUST_ID'], axis=1)
y = data['CUST_ID']

print(X.shape)
print(y.shape)
# Out:
# (8950, 10)
# (8950,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X.to_numpy(), y, test_size=0.20, random_state=13)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (7160, 10)
# (1790, 10)

# %% [markdown]
# # Kesimpulan

# %% [markdown]
# Dari analisis yang telah kami lakukan, diperoleh kesimpulan sebagai berikut:
# - Pada analisa kali ini kami menggunakan model KMeans, PCA, dan bantuan UMAP Application untuk melakukan clustering pada data pengguna kartu kredit
# - Pada KMeans kami memilih 4 cluster berdasarkan pengamatan pada elbow method
# - Alasan penggunaan UMAP Application yaitu karena UMAP bekerja dengan baik dalam menemukan kesamaan dan dapat mempertahankan struktur global data. Dengan menggunakan 2 component berdasarkan UMAP, kami memperoleh kelompok cluster yang lebih seimbang dan masih menemukan beberapa perbedaan besar di antara mereka.
# - Pada analisis ini kami juga membuat beberapa visualisasi menggunakan lineplot, boxplot, histogram, pie chart, dan juga kami melakukan beberapa contoh groupby dan query terhadap data yang ada
# - Untuk mengatasi missing value pada analisis ini kami menggunakan pengisian missing value dengan menggunakan median
